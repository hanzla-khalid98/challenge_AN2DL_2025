# %% [markdown]
# <a href="https://colab.research.google.com/github/hanzla-khalid98/challenge_AN2DL_2025/blob/main/Hybride_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Challenge 1**
#
# ---

# %% [markdown]
# ## Library Import

# %%
# Set seed for reproducibility
SEED = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(SEED)
random.seed(SEED)

# Import PyTorch
import torch
torch.manual_seed(SEED)
from torch import nn
# from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import TensorDataset, DataLoader
logs_dir = "tensorboard"
# !pkill -f tensorboard
# %load_ext tensorboard
# !mkdir -p models

if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True
else:
    device = torch.device("cpu")

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")

# Import other libraries
import copy
import shutil
from itertools import product
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# PyTorch version: 2.8.0+cu126
# Device: cuda

# %%
data = torch.load("dataset.pt")

train_ds = TensorDataset(data["X_train"], data["y_train"])
val_ds   = TensorDataset(data["X_val"], data["y_val"])
test_ds  = TensorDataset(data["X_test"], data["y_test"])

# %%
BATCH_SIZE = 64

# %%
def make_loader(ds, batch_size, shuffle, drop_last):
    # Determine optimal number of worker processes for data loading
    cpu_cores = os.cpu_count() or 2
    num_workers = max(2, min(4, cpu_cores))

    # Create DataLoader with performance optimizations
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=True,  # Faster GPU transfer
        pin_memory_device="cuda" if torch.cuda.is_available() else "",
        prefetch_factor=4,  # Load 4 batches ahead
    )

# %%
# Create data loaders with different settings for each phase
train_loader = make_loader(train_ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
val_loader   = make_loader(val_ds, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)
test_loader  = make_loader(test_ds, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

# %%
# Get one batch from the training data loader
for xb, yb in train_loader:
    input_shape = xb.shape[1:]
    num_classes = len(np.unique(yb))
    break # Stop after getting one batch

# %% [markdown]
# ## 🛠️ **Model Building**

# %%
def recurrent_summary(model, input_size):
    """
    Custom summary function that emulates torchinfo's output while correctly
    counting parameters for RNN/GRU/LSTM layers.

    This function is designed for models whose direct children are
    nn.Linear, nn.RNN, nn.GRU, or nn.LSTM layers.

    Args:
        model (nn.Module): The model to analyze.
        input_size (tuple): Shape of the input tensor (e.g., (seq_len, features)).
    """

    # Dictionary to store output shapes captured by forward hooks
    output_shapes = {}
    # List to track hook handles for later removal
    hooks = []

    def get_hook(name):
        """Factory function to create a forward hook for a specific module."""
        def hook(module, input, output):
            # Handle RNN layer outputs (returns a tuple)
            if isinstance(output, tuple):
                # output[0]: all hidden states with shape (batch, seq_len, hidden*directions)
                shape1 = list(output[0].shape)
                shape1[0] = -1  # Replace batch dimension with -1

                # output[1]: final hidden state h_n (or tuple (h_n, c_n) for LSTM)
                if isinstance(output[1], tuple):  # LSTM case: (h_n, c_n)
                    shape2 = list(output[1][0].shape)  # Extract h_n only
                else:  # RNN/GRU case: h_n only
                    shape2 = list(output[1].shape)

                # Replace batch dimension (middle position) with -1
                shape2[1] = -1

                output_shapes[name] = f"[{shape1}, {shape2}]"

            # Handle standard layer outputs (e.g., Linear)
            else:
                shape = list(output.shape)
                shape[0] = -1  # Replace batch dimension with -1
                output_shapes[name] = f"{shape}"
        return hook

    # 1. Determine the device where model parameters reside
    try:
        device = next(model.parameters()).device
    except StopIteration:
        device = torch.device("cpu")  # Fallback for models without parameters

    # 2. Create a dummy input tensor with batch_size=1
    dummy_input = torch.randn(1, *input_size).to(device)

    # 3. Register forward hooks on target layers
    # Iterate through direct children of the model (e.g., self.rnn, self.classifier)
    for name, module in model.named_children():
        if isinstance(module, (nn.Linear, nn.RNN, nn.GRU, nn.LSTM)):
            # Register the hook and store its handle for cleanup
            hook_handle = module.register_forward_hook(get_hook(name))
            hooks.append(hook_handle)

    # 4. Execute a dummy forward pass in evaluation mode
    model.eval()
    with torch.no_grad():
        try:
            model(dummy_input)
        except Exception as e:
            print(f"Error during dummy forward pass: {e}")
            # Clean up hooks even if an error occurs
            for h in hooks:
                h.remove()
            return

    # 5. Remove all registered hooks
    for h in hooks:
        h.remove()

    # --- 6. Print the summary table ---

    print("-" * 79)
    # Column headers
    print(f"{'Layer (type)':<25} {'Output Shape':<28} {'Param #':<18}")
    print("=" * 79)

    total_params = 0
    total_trainable_params = 0

    # Iterate through modules again to collect and display parameter information
    for name, module in model.named_children():
        if name in output_shapes:
            # Count total and trainable parameters for this module
            module_params = sum(p.numel() for p in module.parameters())
            trainable_params = sum(p.numel() for p in module.parameters() if p.requires_grad)

            total_params += module_params
            total_trainable_params += trainable_params

            # Format strings for display
            layer_name = f"{name} ({type(module).__name__})"
            output_shape_str = str(output_shapes[name])
            params_str = f"{trainable_params:,}"

            print(f"{layer_name:<25} {output_shape_str:<28} {params_str:<15}")

    print("=" * 79)
    print(f"Total params: {total_params:,}")
    print(f"Trainable params: {total_trainable_params:,}")
    print(f"Non-trainable params: {total_params - total_trainable_params:,}")
    print("-" * 79)

# %%
class RecurrentClassifier(nn.Module):
    """
    Generic RNN classifier (RNN, LSTM, GRU).
    Uses the last hidden state for classification.
    """
    def __init__(
            self,
            input_size,
            hidden_size,
            num_layers,
            num_classes,
            rnn_type='GRU',        # 'RNN', 'LSTM', or 'GRU'
            bidirectional=False,
            dropout_rate=0.2
            ):
        super().__init__()

        self.rnn_type = rnn_type
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.bidirectional = bidirectional

        # Map string name to PyTorch RNN class
        rnn_map = {
            'RNN': nn.RNN,
            'LSTM': nn.LSTM,
            'GRU': nn.GRU
        }

        if rnn_type not in rnn_map:
            raise ValueError("rnn_type must be 'RNN', 'LSTM', or 'GRU'")

        rnn_module = rnn_map[rnn_type]

        # Dropout is only applied between layers (if num_layers > 1)
        dropout_val = dropout_rate if num_layers > 1 else 0

        # Create the recurrent layer
        self.rnn = rnn_module(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,       # Input shape: (batch, seq_len, features)
            bidirectional=bidirectional,
            dropout=dropout_val
        )

        # Calculate input size for the final classifier
        if self.bidirectional:
            classifier_input_size = hidden_size * 2 # Concat fwd + bwd
        else:
            classifier_input_size = hidden_size

        # Final classification layer
        self.classifier = nn.Linear(classifier_input_size, num_classes)

    def forward(self, x):
        """
        x shape: (batch_size, seq_length, input_size)
        """

        # rnn_out shape: (batch_size, seq_len, hidden_size * num_directions)
        rnn_out, hidden = self.rnn(x)

        # LSTM returns (h_n, c_n), we only need h_n
        if self.rnn_type == 'LSTM':
            hidden = hidden[0]

        # hidden shape: (num_layers * num_directions, batch_size, hidden_size)

        if self.bidirectional:
            # Reshape to (num_layers, 2, batch_size, hidden_size)
            hidden = hidden.view(self.num_layers, 2, -1, self.hidden_size)

            # Concat last fwd (hidden[-1, 0, ...]) and bwd (hidden[-1, 1, ...])
            # Final shape: (batch_size, hidden_size * 2)
            hidden_to_classify = torch.cat([hidden[-1, 0, :, :], hidden[-1, 1, :, :]], dim=1)
        else:
            # Take the last layer's hidden state
            # Final shape: (batch_size, hidden_size)
            hidden_to_classify = hidden[-1]

        # Get logits
        logits = self.classifier(hidden_to_classify)
        return logits


# Create model and display architecture with parameter count
rnn_model = RecurrentClassifier(
    input_size=input_shape[-1], # Pass the number of features
    hidden_size=128,
    num_layers=2,
    num_classes=num_classes,
    dropout_rate=0.2,
    rnn_type='RNN'
    ).to(device)
recurrent_summary(rnn_model, input_size=input_shape)
# Out:
# -------------------------------------------------------------------------------
# Layer (type)              Output Shape                 Param #
# ===============================================================================
# rnn (RNN)                 [[-1, 50, 128], [2, -1, 128]] 54,400
# classifier (Linear)       [-1, 3]                      387
# ===============================================================================
# Total params: 54,787
# Trainable params: 54,787
# Non-trainable params: 0
# -------------------------------------------------------------------------------

# %%
class HybridLSTMGRUClassifier(nn.Module):

    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_rate=0.2):
        super().__init__()

        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout_rate if num_layers > 1 else 0
        )

        self.gru = nn.GRU(
            input_size=hidden_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout_rate if num_layers > 1 else 0
        )

        self.classifier = nn.Linear(hidden_size * 2, num_classes)

    def forward(self, x):

        lstm_out, (h_lstm, _) = self.lstm(x)
        h_lstm_last = h_lstm[-1]

        gru_out, h_gru = self.gru(lstm_out)
        h_gru_last = h_gru[-1]

        combined = torch.cat((h_lstm_last, h_gru_last), dim=1)

        logits = self.classifier(combined)
        return logits

# %% [markdown]
# ## 🧮 **Network and Training Hyperparameters**

# %%
# Training configuration
LEARNING_RATE = 1e-3
EPOCHS = 500
PATIENCE = 50

# Architecture
HIDDEN_LAYERS = 2        # Hidden layers
HIDDEN_SIZE = 16        # Neurons per layer

# Regularisation
DROPOUT_RATE = 0.6         # Dropout probability
L1_LAMBDA = 1e-4           # L1 penalty
L2_LAMBDA = 1e-3            # L2 penalty

# %%
class_frequency = np.array([0.77, 0.14, 0.09])

class_weights = torch.tensor(1/class_frequency, dtype=torch.float32).to(device)

# Set up loss function and optimizer with class weights and label smoothing
criterion = nn.CrossEntropyLoss(class_weights, label_smoothing=0.1)

# %% [markdown]
# ## 🧠 **Model Training**

# %%
# Initialize best model tracking variables
best_model = None
best_performance = float('-inf')

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, scaler, device, l1_lambda=0, l2_lambda=0):
    """
    Perform one complete training epoch through the entire training dataset.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): Lambda for L1 regularization
        l2_lambda (float): Lambda for L2 regularization

    Returns:
        tuple: (average_loss, f1 score) - Training loss and f1 score for this epoch
    """
    model.train()  # Set model to training mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Iterate through training batches
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        # Move data to device (GPU/CPU)
        inputs, targets = inputs.to(device), targets.to(device)

        # Clear gradients from previous step
        optimizer.zero_grad(set_to_none=True)

        # Forward pass with mixed precision (if CUDA available)
        with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
            logits = model(inputs)
            loss = criterion(logits, targets)

            # Add L1 and L2 regularization
            l1_norm = sum(p.abs().sum() for p in model.parameters())
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l1_lambda * l1_norm + l2_lambda * l2_norm


        # Backward pass with gradient scaling
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Accumulate metrics
        running_loss += loss.item() * inputs.size(0)
        predictions = logits.argmax(dim=1)
        all_predictions.append(predictions.cpu().numpy())
        all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_f1 = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_f1

# %%
def validate_one_epoch(model, val_loader, criterion, device):
    """
    Perform one complete validation epoch through the entire validation dataset.

    Args:
        model (nn.Module): The neural network model to evaluate (must be in eval mode)
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        criterion (nn.Module): Loss function used to calculate validation loss
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)

    Returns:
        tuple: (average_loss, accuracy) - Validation loss and accuracy for this epoch

    Note:
        This function automatically sets the model to evaluation mode and disables
        gradient computation for efficiency during validation.
    """
    model.eval()  # Set model to evaluation mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Disable gradient computation for validation
    with torch.no_grad():
        for inputs, targets in val_loader:
            # Move data to device
            inputs, targets = inputs.to(device), targets.to(device)

            # Forward pass with mixed precision (if CUDA available)
            with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                logits = model(inputs)
                loss = criterion(logits, targets)

            # Accumulate metrics
            running_loss += loss.item() * inputs.size(0)
            predictions = logits.argmax(dim=1)
            all_predictions.append(predictions.cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_accuracy = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_accuracy

# %%
def log_metrics_to_tensorboard(writer, epoch, train_loss, train_f1, val_loss, val_f1, model):
    """
    Log training metrics and model parameters to TensorBoard for visualization.

    Args:
        writer (SummaryWriter): TensorBoard SummaryWriter object for logging
        epoch (int): Current epoch number (used as x-axis in TensorBoard plots)
        train_loss (float): Training loss for this epoch
        train_f1 (float): Training f1 score for this epoch
        val_loss (float): Validation loss for this epoch
        val_f1 (float): Validation f1 score for this epoch
        model (nn.Module): The neural network model (for logging weights/gradients)

    Note:
        This function logs scalar metrics (loss/f1 score) and histograms of model
        parameters and gradients, which helps monitor training progress and detect
        issues like vanishing/exploding gradients.
    """
    # Log scalar metrics
    writer.add_scalar('Loss/Training', train_loss, epoch)
    writer.add_scalar('Loss/Validation', val_loss, epoch)
    writer.add_scalar('F1/Training', train_f1, epoch)
    writer.add_scalar('F1/Validation', val_f1, epoch)

    # Log model parameters and gradients
    for name, param in model.named_parameters():
        if param.requires_grad:
            # Check if the tensor is not empty before adding a histogram
            if param.numel() > 0:
                writer.add_histogram(f'{name}/weights', param.data, epoch)
            if param.grad is not None:
                # Check if the gradient tensor is not empty before adding a histogram
                if param.grad.numel() > 0:
                    if param.grad is not None and torch.isfinite(param.grad).all():
                        writer.add_histogram(f'{name}/gradients', param.grad.data, epoch)

# %%
def fit(model, train_loader, val_loader, epochs, criterion, optimizer, scaler, device,
        l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
        restore_best_weights=True, writer=None, verbose=10, experiment_name=""):
    """
    Train the neural network model on the training data and validate on the validation data.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        epochs (int): Number of training epochs
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): L1 regularization coefficient (default: 0)
        l2_lambda (float): L2 regularization coefficient (default: 0)
        patience (int): Number of epochs to wait for improvement before early stopping (default: 0)
        evaluation_metric (str): Metric to monitor for early stopping (default: "val_f1")
        mode (str): 'max' for maximizing the metric, 'min' for minimizing (default: 'max')
        restore_best_weights (bool): Whether to restore model weights from best epoch (default: True)
        writer (SummaryWriter, optional): TensorBoard SummaryWriter object for logging (default: None)
        verbose (int, optional): Frequency of printing training progress (default: 10)
        experiment_name (str, optional): Experiment name for saving models (default: "")

    Returns:
        tuple: (model, training_history) - Trained model and metrics history
    """

    # Initialize metrics tracking
    training_history = {
        'train_loss': [], 'val_loss': [],
        'train_f1': [], 'val_f1': []
    }

    # Configure early stopping if patience is set
    if patience > 0:
        patience_counter = 0
        best_metric = float('-inf') if mode == 'max' else float('inf')
        best_epoch = 0

    print(f"Training {epochs} epochs...")

    # Main training loop: iterate through epochs
    for epoch in range(1, epochs + 1):

        # Forward pass through training data, compute gradients, update weights
        train_loss, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer, scaler, device, l1_lambda, l2_lambda
        )

        # Evaluate model on validation data without updating weights
        val_loss, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        # Store metrics for plotting and analysis
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_f1'].append(train_f1)
        training_history['val_f1'].append(val_f1)

        # Write metrics to TensorBoard for visualization
        if writer is not None:
            log_metrics_to_tensorboard(
                writer, epoch, train_loss, train_f1, val_loss, val_f1, model
            )

        # Print progress every N epochs or on first epoch
        if verbose > 0:
            if epoch % verbose == 0 or epoch == 1:
                print(f"Epoch {epoch:3d}/{epochs} | "
                    f"Train: Loss={train_loss:.4f}, F1 Score={train_f1:.4f} | "
                    f"Val: Loss={val_loss:.4f}, F1 Score={val_f1:.4f}")

        # Early stopping logic: monitor metric and save best model
        if patience > 0:
            current_metric = training_history[evaluation_metric][-1]
            is_improvement = (current_metric > best_metric) if mode == 'max' else (current_metric < best_metric)

            if is_improvement:
                best_metric = current_metric
                best_epoch = epoch
                torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered after {epoch} epochs.")
                    break

    # Restore best model weights if early stopping was used
    if restore_best_weights and patience > 0:
        model.load_state_dict(torch.load("models/"+experiment_name+'_model.pt'))
        print(f"Best model restored from epoch {best_epoch} with {evaluation_metric} {best_metric:.4f}")

    # Save final model if no early stopping
    if patience == 0:
        torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')

    # Close TensorBoard writer
    if writer is not None:
        writer.close()

    return model, training_history

# %%
hybrid_model = HybridLSTMGRUClassifier(
    input_size=input_shape[-1],
    hidden_size=HIDDEN_SIZE,
    num_layers=HIDDEN_LAYERS,
    num_classes=num_classes,
    dropout_rate=DROPOUT_RATE
).to(device)

# Display model summary
recurrent_summary(hybrid_model, input_size=input_shape)

hparams = {
    "input_size": input_shape[-1], # Pass the number of features
    "hidden_size": HIDDEN_SIZE,
    "num_layers": HIDDEN_LAYERS,
    "num_classes": num_classes,
    "dropout_rate": DROPOUT_RATE
}

torch.save(hparams, "models/hybrid_hparams.pt")

# TensorBoard setup
experiment_name = "hybrid_lstm_gru"
writer = SummaryWriter(f"./{logs_dir}/{experiment_name}")
x = torch.randn(1, input_shape[0], input_shape[1]).to(device)
writer.add_graph(hybrid_model, x)

# Optimizer with L2 regularization
optimizer = torch.optim.AdamW(
    hybrid_model.parameters(),
    lr=LEARNING_RATE,
    weight_decay=L2_LAMBDA
)

# Mixed precision for GPU
scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

print(f"Hybrid LSTM+GRU model ready on device: {device}")
# Out:
# -------------------------------------------------------------------------------
# Layer (type)              Output Shape                 Param #
# ===============================================================================
# lstm (LSTM)               [[-1, 50, 16], [2, -1, 16]]  5,696
# gru (GRU)                 [[-1, 50, 16], [2, -1, 16]]  3,264
# classifier (Linear)       [-1, 3]                      99
# ===============================================================================
# Total params: 9,059
# Trainable params: 9,059
# Non-trainable params: 0
# -------------------------------------------------------------------------------
# Hybrid LSTM+GRU model ready on device: cuda

# %%
# %%time
# Train hybrid model and track training history
hybrid_model, training_history = fit(
    model=hybrid_model,
    train_loader=train_loader,
    val_loader=val_loader,
    epochs=EPOCHS,
    criterion=criterion,
    optimizer=optimizer,
    scaler=scaler,
    device=device,
    writer=writer,
    verbose=1,
    experiment_name="hybrid_lstm_gru",
    patience=PATIENCE
)

# Update best model if current performance is superior
if training_history['val_f1'][-1] > best_performance:
    best_model = hybrid_model
    best_performance = training_history['val_f1'][-1]
# Out:
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.2297, F1 Score=0.0589 | Val: Loss=1.2988, F1 Score=0.1270
# Epoch   2/500 | Train: Loss=1.2109, F1 Score=0.4313 | Val: Loss=1.3838, F1 Score=0.0327
# Epoch   3/500 | Train: Loss=1.1939, F1 Score=0.5595 | Val: Loss=1.2532, F1 Score=0.6136
# Epoch   4/500 | Train: Loss=1.1816, F1 Score=0.5772 | Val: Loss=1.2635, F1 Score=0.6224
# Epoch   5/500 | Train: Loss=1.1473, F1 Score=0.6882 | Val: Loss=1.2150, F1 Score=0.6422
# Epoch   6/500 | Train: Loss=1.1151, F1 Score=0.7402 | Val: Loss=1.1833, F1 Score=0.7961
# Epoch   7/500 | Train: Loss=1.0906, F1 Score=0.7690 | Val: Loss=1.1688, F1 Score=0.7982
# Epoch   8/500 | Train: Loss=1.0884, F1 Score=0.7784 | Val: Loss=1.1741, F1 Score=0.8017
# Epoch   9/500 | Train: Loss=1.0585, F1 Score=0.8028 | Val: Loss=1.1464, F1 Score=0.7886
# Epoch  10/500 | Train: Loss=1.0120, F1 Score=0.8077 | Val: Loss=1.1715, F1 Score=0.7658
# Epoch  11/500 | Train: Loss=0.9507, F1 Score=0.8197 | Val: Loss=1.1997, F1 Score=0.7866
# Epoch  12/500 | Train: Loss=0.9220, F1 Score=0.8445 | Val: Loss=1.1279, F1 Score=0.8265
# Epoch  13/500 | Train: Loss=0.9111, F1 Score=0.8384 | Val: Loss=1.1148, F1 Score=0.8153
# Epoch  14/500 | Train: Loss=0.8832, F1 Score=0.8560 | Val: Loss=1.0915, F1 Score=0.8431
# Epoch  15/500 | Train: Loss=0.8640, F1 Score=0.8657 | Val: Loss=1.0874, F1 Score=0.8317
# Epoch  16/500 | Train: Loss=0.8677, F1 Score=0.8567 | Val: Loss=1.0686, F1 Score=0.8499
# Epoch  17/500 | Train: Loss=0.8408, F1 Score=0.8631 | Val: Loss=1.1503, F1 Score=0.7984
# Epoch  18/500 | Train: Loss=0.8463, F1 Score=0.8592 | Val: Loss=1.1314, F1 Score=0.7940
# Epoch  19/500 | Train: Loss=0.8442, F1 Score=0.8632 | Val: Loss=1.1030, F1 Score=0.8369
# Epoch  20/500 | Train: Loss=0.8150, F1 Score=0.8649 | Val: Loss=1.0386, F1 Score=0.8505
# Epoch  21/500 | Train: Loss=0.8560, F1 Score=0.8594 | Val: Loss=1.1368, F1 Score=0.8221
# Epoch  22/500 | Train: Loss=0.8009, F1 Score=0.8756 | Val: Loss=1.0622, F1 Score=0.8521
# Epoch  23/500 | Train: Loss=0.8348, F1 Score=0.8654 | Val: Loss=1.0550, F1 Score=0.8445
# Epoch  24/500 | Train: Loss=0.7854, F1 Score=0.8863 | Val: Loss=1.0188, F1 Score=0.8446
# Epoch  25/500 | Train: Loss=0.7812, F1 Score=0.8806 | Val: Loss=1.0987, F1 Score=0.8437
# Epoch  26/500 | Train: Loss=0.7733, F1 Score=0.8855 | Val: Loss=1.0256, F1 Score=0.8596
# Epoch  27/500 | Train: Loss=0.7871, F1 Score=0.8751 | Val: Loss=1.0873, F1 Score=0.8337
# Epoch  28/500 | Train: Loss=0.8150, F1 Score=0.8741 | Val: Loss=1.0646, F1 Score=0.8493
# Epoch  29/500 | Train: Loss=0.7716, F1 Score=0.8913 | Val: Loss=1.0056, F1 Score=0.8790
# Epoch  30/500 | Train: Loss=0.7653, F1 Score=0.8901 | Val: Loss=1.0400, F1 Score=0.8580
# Epoch  31/500 | Train: Loss=0.7437, F1 Score=0.8913 | Val: Loss=1.0470, F1 Score=0.8565
# Epoch  32/500 | Train: Loss=0.7688, F1 Score=0.8870 | Val: Loss=1.0615, F1 Score=0.8364
# Epoch  33/500 | Train: Loss=0.7380, F1 Score=0.8899 | Val: Loss=1.0703, F1 Score=0.8411
# Epoch  34/500 | Train: Loss=0.7258, F1 Score=0.8974 | Val: Loss=1.0742, F1 Score=0.8474
# Epoch  35/500 | Train: Loss=0.7295, F1 Score=0.8883 | Val: Loss=1.0267, F1 Score=0.8527
# Epoch  36/500 | Train: Loss=0.7069, F1 Score=0.8946 | Val: Loss=1.0566, F1 Score=0.8459
# Epoch  37/500 | Train: Loss=0.7259, F1 Score=0.8880 | Val: Loss=1.0255, F1 Score=0.8545
# Epoch  38/500 | Train: Loss=0.7225, F1 Score=0.8960 | Val: Loss=1.0389, F1 Score=0.8603
# Epoch  39/500 | Train: Loss=0.7007, F1 Score=0.8986 | Val: Loss=1.0769, F1 Score=0.8519
# Epoch  40/500 | Train: Loss=0.6955, F1 Score=0.8993 | Val: Loss=1.0068, F1 Score=0.8590
# Epoch  41/500 | Train: Loss=0.6890, F1 Score=0.8996 | Val: Loss=1.0224, F1 Score=0.8518
# Epoch  42/500 | Train: Loss=0.6902, F1 Score=0.9030 | Val: Loss=1.0278, F1 Score=0.8368
# Epoch  43/500 | Train: Loss=0.6921, F1 Score=0.9017 | Val: Loss=1.0036, F1 Score=0.8669
# Epoch  44/500 | Train: Loss=0.6860, F1 Score=0.9011 | Val: Loss=1.1014, F1 Score=0.8625
# Epoch  45/500 | Train: Loss=0.6913, F1 Score=0.9036 | Val: Loss=1.0734, F1 Score=0.8641
# Epoch  46/500 | Train: Loss=0.6979, F1 Score=0.9011 | Val: Loss=1.1125, F1 Score=0.8369
# Epoch  47/500 | Train: Loss=0.6813, F1 Score=0.9073 | Val: Loss=1.0317, F1 Score=0.8616
# Epoch  48/500 | Train: Loss=0.6707, F1 Score=0.9096 | Val: Loss=1.0849, F1 Score=0.8579
# Epoch  49/500 | Train: Loss=0.6654, F1 Score=0.9101 | Val: Loss=1.0452, F1 Score=0.8680
# Epoch  50/500 | Train: Loss=0.6723, F1 Score=0.9067 | Val: Loss=1.1676, F1 Score=0.8378
# Epoch  51/500 | Train: Loss=0.6838, F1 Score=0.9084 | Val: Loss=1.0193, F1 Score=0.8701
# Epoch  52/500 | Train: Loss=0.6722, F1 Score=0.9112 | Val: Loss=1.0248, F1 Score=0.8635
# Epoch  53/500 | Train: Loss=0.6640, F1 Score=0.9099 | Val: Loss=1.0070, F1 Score=0.8797
# Epoch  54/500 | Train: Loss=0.6799, F1 Score=0.9126 | Val: Loss=1.0433, F1 Score=0.8659
# Epoch  55/500 | Train: Loss=0.6672, F1 Score=0.9169 | Val: Loss=1.0075, F1 Score=0.8708
# Epoch  56/500 | Train: Loss=0.6616, F1 Score=0.9207 | Val: Loss=1.0109, F1 Score=0.8613
# Epoch  57/500 | Train: Loss=0.6537, F1 Score=0.9184 | Val: Loss=1.0174, F1 Score=0.8736
# Epoch  58/500 | Train: Loss=0.6549, F1 Score=0.9257 | Val: Loss=1.0808, F1 Score=0.8525
# Epoch  59/500 | Train: Loss=0.6763, F1 Score=0.9093 | Val: Loss=0.9779, F1 Score=0.8812
# Epoch  60/500 | Train: Loss=0.6500, F1 Score=0.9257 | Val: Loss=0.9635, F1 Score=0.8906
# Epoch  61/500 | Train: Loss=0.6499, F1 Score=0.9221 | Val: Loss=1.0474, F1 Score=0.8245
# Epoch  62/500 | Train: Loss=0.6767, F1 Score=0.9130 | Val: Loss=0.9694, F1 Score=0.8815
# Epoch  63/500 | Train: Loss=0.6521, F1 Score=0.9266 | Val: Loss=1.0365, F1 Score=0.8699
# Epoch  64/500 | Train: Loss=0.6548, F1 Score=0.9180 | Val: Loss=1.1167, F1 Score=0.8556
# Epoch  65/500 | Train: Loss=0.6574, F1 Score=0.9222 | Val: Loss=1.0772, F1 Score=0.8692
# Epoch  66/500 | Train: Loss=0.6454, F1 Score=0.9282 | Val: Loss=0.9891, F1 Score=0.8585
# Epoch  67/500 | Train: Loss=0.6453, F1 Score=0.9250 | Val: Loss=1.0407, F1 Score=0.8527
# Epoch  68/500 | Train: Loss=0.6464, F1 Score=0.9248 | Val: Loss=1.0354, F1 Score=0.8646
# Epoch  69/500 | Train: Loss=0.6374, F1 Score=0.9280 | Val: Loss=1.0434, F1 Score=0.8610
# Epoch  70/500 | Train: Loss=0.6433, F1 Score=0.9293 | Val: Loss=0.9997, F1 Score=0.8766
# Epoch  71/500 | Train: Loss=0.6428, F1 Score=0.9293 | Val: Loss=1.0011, F1 Score=0.8585
# Epoch  72/500 | Train: Loss=0.6462, F1 Score=0.9301 | Val: Loss=1.0229, F1 Score=0.8699
# Epoch  73/500 | Train: Loss=0.6335, F1 Score=0.9291 | Val: Loss=0.9980, F1 Score=0.8784
# Epoch  74/500 | Train: Loss=0.6590, F1 Score=0.9262 | Val: Loss=1.0116, F1 Score=0.8700
# Epoch  75/500 | Train: Loss=0.6602, F1 Score=0.9212 | Val: Loss=1.0291, F1 Score=0.8750
# Epoch  76/500 | Train: Loss=0.6572, F1 Score=0.9219 | Val: Loss=0.9914, F1 Score=0.8801
# Epoch  77/500 | Train: Loss=0.6334, F1 Score=0.9302 | Val: Loss=1.0377, F1 Score=0.8713
# Epoch  78/500 | Train: Loss=0.6540, F1 Score=0.9291 | Val: Loss=0.9767, F1 Score=0.8773
# Epoch  79/500 | Train: Loss=0.6363, F1 Score=0.9326 | Val: Loss=0.9573, F1 Score=0.8764
# Epoch  80/500 | Train: Loss=0.6356, F1 Score=0.9340 | Val: Loss=1.0398, F1 Score=0.8631
# Epoch  81/500 | Train: Loss=0.6243, F1 Score=0.9378 | Val: Loss=0.9667, F1 Score=0.8780
# Epoch  82/500 | Train: Loss=0.6262, F1 Score=0.9363 | Val: Loss=0.9468, F1 Score=0.8835
# Epoch  83/500 | Train: Loss=0.6327, F1 Score=0.9332 | Val: Loss=0.9883, F1 Score=0.8862
# Epoch  84/500 | Train: Loss=0.6330, F1 Score=0.9343 | Val: Loss=0.9934, F1 Score=0.8750
# Epoch  85/500 | Train: Loss=0.6280, F1 Score=0.9345 | Val: Loss=0.9758, F1 Score=0.8932
# Epoch  86/500 | Train: Loss=0.6383, F1 Score=0.9346 | Val: Loss=1.0297, F1 Score=0.8530
# Epoch  87/500 | Train: Loss=0.6177, F1 Score=0.9430 | Val: Loss=0.9959, F1 Score=0.8720
# Epoch  88/500 | Train: Loss=0.6258, F1 Score=0.9384 | Val: Loss=0.9698, F1 Score=0.8816
# Epoch  89/500 | Train: Loss=0.6194, F1 Score=0.9400 | Val: Loss=0.9537, F1 Score=0.8884
# Epoch  90/500 | Train: Loss=0.6335, F1 Score=0.9347 | Val: Loss=0.9864, F1 Score=0.8820
# Epoch  91/500 | Train: Loss=0.6131, F1 Score=0.9431 | Val: Loss=0.9335, F1 Score=0.8862
# Epoch  92/500 | Train: Loss=0.6264, F1 Score=0.9350 | Val: Loss=0.9532, F1 Score=0.8884
# Epoch  93/500 | Train: Loss=0.6596, F1 Score=0.9276 | Val: Loss=0.9504, F1 Score=0.8876
# Epoch  94/500 | Train: Loss=0.6154, F1 Score=0.9420 | Val: Loss=1.0273, F1 Score=0.8783
# Epoch  95/500 | Train: Loss=0.6250, F1 Score=0.9418 | Val: Loss=0.9476, F1 Score=0.8878
# Epoch  96/500 | Train: Loss=0.6233, F1 Score=0.9417 | Val: Loss=1.0050, F1 Score=0.8788
# Epoch  97/500 | Train: Loss=0.6369, F1 Score=0.9328 | Val: Loss=1.0114, F1 Score=0.8670
# Epoch  98/500 | Train: Loss=0.6292, F1 Score=0.9330 | Val: Loss=0.9030, F1 Score=0.8893
# Epoch  99/500 | Train: Loss=0.6220, F1 Score=0.9457 | Val: Loss=0.9415, F1 Score=0.8928
# Epoch 100/500 | Train: Loss=0.6192, F1 Score=0.9429 | Val: Loss=0.9284, F1 Score=0.8805
# Epoch 101/500 | Train: Loss=0.6168, F1 Score=0.9471 | Val: Loss=1.0578, F1 Score=0.8650
# Epoch 102/500 | Train: Loss=0.6169, F1 Score=0.9449 | Val: Loss=1.0285, F1 Score=0.8805
# Epoch 103/500 | Train: Loss=0.6101, F1 Score=0.9490 | Val: Loss=1.0198, F1 Score=0.8765
# Epoch 104/500 | Train: Loss=0.6887, F1 Score=0.9230 | Val: Loss=0.9963, F1 Score=0.8929
# Epoch 105/500 | Train: Loss=0.7011, F1 Score=0.9147 | Val: Loss=1.0369, F1 Score=0.8436
# Epoch 106/500 | Train: Loss=0.6362, F1 Score=0.9389 | Val: Loss=1.0057, F1 Score=0.8701
# Epoch 107/500 | Train: Loss=0.6262, F1 Score=0.9405 | Val: Loss=0.9745, F1 Score=0.8801
# Epoch 108/500 | Train: Loss=0.6172, F1 Score=0.9457 | Val: Loss=1.0270, F1 Score=0.8728
# Epoch 109/500 | Train: Loss=0.6252, F1 Score=0.9440 | Val: Loss=0.9518, F1 Score=0.8679
# Epoch 110/500 | Train: Loss=0.6108, F1 Score=0.9505 | Val: Loss=0.9960, F1 Score=0.8790
# Epoch 111/500 | Train: Loss=0.6092, F1 Score=0.9474 | Val: Loss=0.9323, F1 Score=0.8853
# Epoch 112/500 | Train: Loss=0.6032, F1 Score=0.9516 | Val: Loss=0.9751, F1 Score=0.8982
# Epoch 113/500 | Train: Loss=0.6047, F1 Score=0.9533 | Val: Loss=0.9715, F1 Score=0.8974
# Epoch 114/500 | Train: Loss=0.6110, F1 Score=0.9487 | Val: Loss=0.9951, F1 Score=0.8823
# Epoch 115/500 | Train: Loss=0.6095, F1 Score=0.9490 | Val: Loss=0.9845, F1 Score=0.8700
# Epoch 116/500 | Train: Loss=0.6417, F1 Score=0.9444 | Val: Loss=0.9526, F1 Score=0.8924
# Epoch 117/500 | Train: Loss=0.6055, F1 Score=0.9507 | Val: Loss=0.9764, F1 Score=0.9005
# Epoch 118/500 | Train: Loss=0.6017, F1 Score=0.9530 | Val: Loss=0.8790, F1 Score=0.9104
# Epoch 119/500 | Train: Loss=0.6039, F1 Score=0.9485 | Val: Loss=0.8545, F1 Score=0.9213
# Epoch 120/500 | Train: Loss=0.5922, F1 Score=0.9581 | Val: Loss=0.9368, F1 Score=0.8861
# Epoch 121/500 | Train: Loss=0.5996, F1 Score=0.9600 | Val: Loss=0.9546, F1 Score=0.8876
# Epoch 122/500 | Train: Loss=0.6212, F1 Score=0.9478 | Val: Loss=0.9614, F1 Score=0.8873
# Epoch 123/500 | Train: Loss=0.6021, F1 Score=0.9534 | Val: Loss=1.0333, F1 Score=0.8779
# Epoch 124/500 | Train: Loss=0.6235, F1 Score=0.9476 | Val: Loss=0.9292, F1 Score=0.8885
# Epoch 125/500 | Train: Loss=0.5997, F1 Score=0.9522 | Val: Loss=0.9878, F1 Score=0.8743
# Epoch 126/500 | Train: Loss=0.6257, F1 Score=0.9495 | Val: Loss=0.9642, F1 Score=0.8966
# Epoch 127/500 | Train: Loss=0.6052, F1 Score=0.9554 | Val: Loss=0.8941, F1 Score=0.8983
# Epoch 128/500 | Train: Loss=0.6105, F1 Score=0.9506 | Val: Loss=0.9160, F1 Score=0.9109
# Epoch 129/500 | Train: Loss=0.6029, F1 Score=0.9543 | Val: Loss=1.0253, F1 Score=0.8724
# Epoch 130/500 | Train: Loss=0.6035, F1 Score=0.9523 | Val: Loss=0.9184, F1 Score=0.8715
# Epoch 131/500 | Train: Loss=0.6047, F1 Score=0.9518 | Val: Loss=0.9892, F1 Score=0.8729
# Epoch 132/500 | Train: Loss=0.6174, F1 Score=0.9467 | Val: Loss=0.9121, F1 Score=0.8936
# Epoch 133/500 | Train: Loss=0.5927, F1 Score=0.9571 | Val: Loss=0.9372, F1 Score=0.8723
# Epoch 134/500 | Train: Loss=0.6031, F1 Score=0.9541 | Val: Loss=0.9411, F1 Score=0.8935
# Epoch 135/500 | Train: Loss=0.6287, F1 Score=0.9488 | Val: Loss=0.8682, F1 Score=0.9140
# Epoch 136/500 | Train: Loss=0.6029, F1 Score=0.9500 | Val: Loss=0.9502, F1 Score=0.8932
# Epoch 137/500 | Train: Loss=0.5936, F1 Score=0.9568 | Val: Loss=0.9585, F1 Score=0.8890
# Epoch 138/500 | Train: Loss=0.6023, F1 Score=0.9524 | Val: Loss=1.0184, F1 Score=0.8631
# Epoch 139/500 | Train: Loss=0.6077, F1 Score=0.9532 | Val: Loss=0.8625, F1 Score=0.9181
# Epoch 140/500 | Train: Loss=0.6282, F1 Score=0.9413 | Val: Loss=0.8835, F1 Score=0.9174
# Epoch 141/500 | Train: Loss=0.5896, F1 Score=0.9582 | Val: Loss=0.8293, F1 Score=0.9081
# Epoch 142/500 | Train: Loss=0.5929, F1 Score=0.9566 | Val: Loss=0.9174, F1 Score=0.8959
# Epoch 143/500 | Train: Loss=0.6158, F1 Score=0.9500 | Val: Loss=0.9403, F1 Score=0.8916
# Epoch 144/500 | Train: Loss=0.5953, F1 Score=0.9594 | Val: Loss=0.9710, F1 Score=0.9010
# Epoch 145/500 | Train: Loss=0.5980, F1 Score=0.9561 | Val: Loss=0.9334, F1 Score=0.8938
# Epoch 146/500 | Train: Loss=0.5936, F1 Score=0.9592 | Val: Loss=0.9408, F1 Score=0.8979
# Epoch 147/500 | Train: Loss=0.5926, F1 Score=0.9599 | Val: Loss=0.9117, F1 Score=0.9178
# Epoch 148/500 | Train: Loss=0.5930, F1 Score=0.9578 | Val: Loss=0.9571, F1 Score=0.8762
# Epoch 149/500 | Train: Loss=0.6011, F1 Score=0.9526 | Val: Loss=0.9716, F1 Score=0.8832
# Epoch 150/500 | Train: Loss=0.5922, F1 Score=0.9592 | Val: Loss=0.9067, F1 Score=0.8971
# Epoch 151/500 | Train: Loss=0.5929, F1 Score=0.9579 | Val: Loss=0.9693, F1 Score=0.8931
# Epoch 152/500 | Train: Loss=0.5885, F1 Score=0.9645 | Val: Loss=0.8701, F1 Score=0.8996
# Epoch 153/500 | Train: Loss=0.5904, F1 Score=0.9619 | Val: Loss=0.9564, F1 Score=0.8995
# Epoch 154/500 | Train: Loss=0.5855, F1 Score=0.9658 | Val: Loss=0.9210, F1 Score=0.8930
# Epoch 155/500 | Train: Loss=0.5891, F1 Score=0.9667 | Val: Loss=0.9725, F1 Score=0.8917
# Epoch 156/500 | Train: Loss=0.5825, F1 Score=0.9681 | Val: Loss=0.8771, F1 Score=0.9097
# Epoch 157/500 | Train: Loss=0.5898, F1 Score=0.9631 | Val: Loss=0.9699, F1 Score=0.8981
# Epoch 158/500 | Train: Loss=0.5892, F1 Score=0.9642 | Val: Loss=0.9058, F1 Score=0.9081
# Epoch 159/500 | Train: Loss=0.5893, F1 Score=0.9645 | Val: Loss=0.9334, F1 Score=0.8957
# Epoch 160/500 | Train: Loss=0.6252, F1 Score=0.9419 | Val: Loss=0.9452, F1 Score=0.9099
# Epoch 161/500 | Train: Loss=0.5863, F1 Score=0.9620 | Val: Loss=0.9124, F1 Score=0.9078
# Epoch 162/500 | Train: Loss=0.5816, F1 Score=0.9670 | Val: Loss=0.9459, F1 Score=0.8946
# Epoch 163/500 | Train: Loss=0.5849, F1 Score=0.9631 | Val: Loss=0.8865, F1 Score=0.9110
# Epoch 164/500 | Train: Loss=0.6051, F1 Score=0.9529 | Val: Loss=0.9240, F1 Score=0.9047
# Epoch 165/500 | Train: Loss=0.5825, F1 Score=0.9651 | Val: Loss=0.9242, F1 Score=0.9017
# Epoch 166/500 | Train: Loss=0.5865, F1 Score=0.9633 | Val: Loss=0.9352, F1 Score=0.9065
# Epoch 167/500 | Train: Loss=0.5818, F1 Score=0.9641 | Val: Loss=0.9658, F1 Score=0.9020
# Epoch 168/500 | Train: Loss=0.5795, F1 Score=0.9675 | Val: Loss=0.9386, F1 Score=0.9022
# Epoch 169/500 | Train: Loss=0.6074, F1 Score=0.9554 | Val: Loss=0.9297, F1 Score=0.9123
# Early stopping triggered after 169 epochs.
# Best model restored from epoch 119 with val_f1 0.9213
# CPU times: user 5min 9s, sys: 28.4 s, total: 5min 38s
# Wall time: 5min 47s

# %%
# @title Plot Hitory
# Create a figure with two side-by-side subplots (two columns)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 5))

# Plot of training and validation loss on the first axis
ax1.plot(training_history['train_loss'], label='Training loss', alpha=0.3, color='#ff7f0e', linestyle='--')
ax1.plot(training_history['val_loss'], label='Validation loss', alpha=0.9, color='#ff7f0e')
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=0.3)

# Plot of training and validation accuracy on the second axis
ax2.plot(training_history['train_f1'], label='Training f1', alpha=0.3, color='#ff7f0e', linestyle='--')
ax2.plot(training_history['val_f1'], label='Validation f1', alpha=0.9, color='#ff7f0e')
ax2.set_title('F1 Score')
ax2.legend()
ax2.grid(alpha=0.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %%
# @title Plot Confusion Matrix
# Collect predictions and ground truth labels
val_preds, val_targets = [], []
with torch.no_grad():  # Disable gradient computation for inference
    for xb, yb in val_loader:
        xb = xb.to(device)

        # Forward pass: get model predictions
        logits = hybrid_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        # Store batch results
        val_preds.append(preds)
        val_targets.append(yb.numpy())

# Combine all batches into single arrays
val_preds = np.concatenate(val_preds)
val_targets = np.concatenate(val_targets)

# Calculate overall validation metrics
val_acc = accuracy_score(val_targets, val_preds)
val_prec = precision_score(val_targets, val_preds, average='weighted')
val_rec = recall_score(val_targets, val_preds, average='weighted')
val_f1 = f1_score(val_targets, val_preds, average='weighted')
print(f"Accuracy over the validation set: {val_acc:.4f}")
print(f"Precision over the validation set: {val_prec:.4f}")
print(f"Recall over the validation set: {val_rec:.4f}")
print(f"F1 score over the validation set: {val_f1:.4f}")

# Generate confusion matrix for detailed error analysis
cm = confusion_matrix(val_targets, val_preds)

# Create numeric labels for heatmap annotation
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Visualise confusion matrix
plt.figure(figsize=(8, 7))
sns.heatmap(cm, annot=labels, fmt='',
            cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix — Validation Set')
plt.tight_layout()
plt.show()
# Out:
# Accuracy over the validation set: 0.9313
# Precision over the validation set: 0.9307
# Recall over the validation set: 0.9313
# F1 score over the validation set: 0.9300

# %% [markdown]
# # Hyperparameter tuning

# %%
# Cross-validation
K = 5                # Number of splits (5 and 10 are considered good values)
N_VAL_USERS = 60        # Number of users for validation split
N_TEST_USERS = 60         # Number of users for test split

# Training
EPOCHS = 500             # Maximum epochs (increase to improve performance)
PATIENCE = 50            # Early stopping patience (increase to improve performance)
VERBOSE = 10             # Print frequency

# Optimisation
LEARNING_RATE = 1e-4     # Learning rate # Reduced learning rate
BATCH_SIZE = 64         # Batch size
WINDOW_SIZE = 50        # Input window size
STRIDE = 10              # Input stride

# Architecture
HIDDEN_LAYERS = 2        # Hidden layers
HIDDEN_SIZE = 128        # Neurons per layer
RNN_TYPE = 'Hybrid'         # Type of RNN architecture
BIDIRECTIONAL = False    # Bidirectional RNN

# Regularisation
DROPOUT_RATE = 0.3       # Dropout probability
L1_LAMBDA = 0           # L1 penalty
L2_LAMBDA = 0            # L2 penalty

# Training utilities
criterion = nn.CrossEntropyLoss()

# %%
from preprocessing import *


def k_shuffle_split_cross_validation_round_rnn(df_training, df_labels, epochs, criterion, device,
                            k, n_val_users, n_test_users, batch_size, hidden_layers, hidden_size, learning_rate, dropout_rate,
                            window_size, stride,
                            l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
                            restore_best_weights=True, writer=None, verbose=10, seed=42, experiment_name=""):
    """
    Perform K-fold shuffle split cross-validation with user-based splitting for time series data.

    Args:
        df: DataFrame with columns ['user_id', 'activity', 'x_axis', 'y_axis', 'z_axis', 'id']
        epochs: Number of training epochs
        criterion: Loss function
        device: torch.device for computation
        k: Number of cross-validation splits
        n_val_users: Number of users for validation set
        n_test_users: Number of users for test set
        batch_size: Batch size for training
        hidden_layers: Number of recurrent layers
        hidden_size: Hidden state dimensionality
        learning_rate: Learning rate for optimizer
        dropout_rate: Dropout rate
        window_size: Length of sliding windows
        stride: Step size for sliding windows
        rnn_type: Type of RNN ('RNN', 'LSTM', 'GRU')
        bidirectional: Whether to use bidirectional RNN
        l1_lambda: L1 regularization coefficient (if used)
        l2_lambda: L2 regularization coefficient (weight_decay)
        patience: Early stopping patience
        evaluation_metric: Metric to monitor for early stopping
        mode: 'max' or 'min' for evaluation metric
        restore_best_weights: Whether to restore best weights after training
        writer: TensorBoard writer
        verbose: Verbosithy level
        seed: Random seed
        experiment_name: Name for experiment logging

    Returns:
        fold_losses: Dict with validation losses for each split
        fold_metrics: Dict with validation F1 scores for each split
        best_scores: Dict with best F1 score for each split plus mean and std
    """

    # Initialise containers for results across all splits
    fold_losses = {}
    fold_metrics = {}
    best_scores = {}

    # Get model architecture parameters
    in_features = 37
    num_classes = len(df_labels['label'].unique())


    # Iterate through K random splits
    for split_idx in range(k):

        if verbose > 0:
            print(f"Split {split_idx+1}/{k}")

        df_train, df_val, df_test = split_dataset(df_training, "sample_index", n_val_users, n_test_users, SEED + split_idx)

        # Define a mapping of activity names to integer labels
        df_labels_cleaned = label_mapping(df_labels.dropna(subset=['label']))

        df_train = feature_mapping(df_train)
        df_val = feature_mapping(df_val)
        df_test = feature_mapping(df_test)

        scale_columns = list(df_train.columns[2:5]) + list(df_train.columns[9:])

        df_train = min_max_normalize(df_train, df_train, scale_columns)
        df_val = min_max_normalize(df_train, df_val, scale_columns)
        df_test = min_max_normalize(df_train, df_test, scale_columns)


        if verbose > 0:
            print(f"  Training set shape: {df_train.shape}")
            print(f"  Validation set shape: {df_val.shape}")
            print(f"  Test set shape: {df_test.shape}")

        X_train, y_train = build_sequences(
            df_train, df_labels_cleaned, window_size, stride)

        X_val, y_val = build_sequences(
            df_val, df_labels_cleaned, window_size, stride)

        X_test, y_test = build_sequences(
            df_test, df_labels_cleaned, window_size, stride)

        if verbose > 0:
            print(f"  Training sequences shape: {X_train.shape}")
            print(f"  Validation sequences shape: {X_val.shape}")
            print(f"  Test sequences shape: {X_test.shape}")

        # Create PyTorch datasets
        train_ds = TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train).to(torch.long))
        val_ds   = TensorDataset(torch.from_numpy(X_val), torch.from_numpy(y_val).to(torch.long))
        test_ds  = TensorDataset(torch.from_numpy(X_test), torch.from_numpy(y_test).to(torch.long))

        # Create data loaders
        train_loader = make_loader(train_ds, batch_size=batch_size, shuffle=True, drop_last=False)
        val_loader   = make_loader(val_ds, batch_size=batch_size, shuffle=False, drop_last=False)
        test_loader  = make_loader(test_ds, batch_size=batch_size, shuffle=False, drop_last=False)

        # Initialise model architecture for each split
        model = HybridLSTMGRUClassifier(
            input_size=in_features,
            hidden_size=hidden_size,
            num_layers=hidden_layers,
            num_classes=num_classes,
            dropout_rate=dropout_rate
            #bidirectional=bidirectional,
            #rnn_type=rnn_type
        ).to(device)
        hparams = {
          "input_size": input_shape[-1], # Pass the number of features
          "hidden_size": HIDDEN_SIZE,
          "num_layers": HIDDEN_LAYERS,
          "num_classes": num_classes,
          "dropout_rate": DROPOUT_RATE
        }

        torch.save(hparams, "models/hybrid_hparams.pt")

        # Define optimizer with L2 regularization
        optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=l2_lambda)

        # Enable mixed precision training for GPU acceleration
        split_scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

        # Create directory for model checkpoints
        os.makedirs(f"models/{experiment_name}", exist_ok=True)

        # Train model on current split
        model, training_history = fit(
            model=model,
            train_loader=train_loader,
            val_loader=val_loader,
            epochs=epochs,
            criterion=criterion,
            optimizer=optimizer,
            scaler=split_scaler,
            device=device,
            writer=writer,
            patience=patience,
            verbose=verbose,
            l1_lambda=l1_lambda,
            evaluation_metric=evaluation_metric,
            mode=mode,
            restore_best_weights=restore_best_weights,
            experiment_name=experiment_name+"/split_"+str(split_idx)
        )

        # Store results for this split
        fold_losses[f"split_{split_idx}"] = training_history['val_loss']
        fold_metrics[f"split_{split_idx}"] = training_history['val_f1']
        best_scores[f"split_{split_idx}"] = max(training_history['val_f1'])

    # Compute mean and standard deviation of best scores across splits
    best_scores["mean"] = np.mean([best_scores[k] for k in best_scores.keys() if k.startswith("split_")])
    best_scores["std"] = np.std([best_scores[k] for k in best_scores.keys() if k.startswith("split_")])

    if verbose > 0:
        print(f"Best score: {best_scores['mean']:.4f}±{best_scores['std']:.4f}")

    return fold_losses, fold_metrics, best_scores

# %%
df_training = pd.read_csv("/content/pirate_pain_train.csv")
df_labels = pd.read_csv("/content/pirate_pain_train_labels.csv")

# %%
# %%time
# Execute K-fold cross-validation with baseline configuration
losses, metrics, best_scores = k_shuffle_split_cross_validation_round_rnn(
    df_training=df_training,
    df_labels=df_labels,
    epochs=EPOCHS,
    criterion=criterion,
    device=device,
    k=K,
    batch_size=BATCH_SIZE,
    hidden_layers=HIDDEN_LAYERS,
    hidden_size=HIDDEN_SIZE,
    learning_rate=LEARNING_RATE,
    dropout_rate=DROPOUT_RATE,
    l1_lambda=L1_LAMBDA,
    l2_lambda=L2_LAMBDA,
    verbose=VERBOSE,
    patience=PATIENCE,
    seed=SEED,
    experiment_name="hybrid_baseline",
    n_val_users=N_VAL_USERS,
    n_test_users=N_TEST_USERS,
    window_size=WINDOW_SIZE,
    stride=STRIDE
)
# Out:
# Split 1/5
#   Training set shape: (86560, 40)
#   Validation set shape: (9600, 40)
#   Test set shape: (9600, 40)
#   Training sequences shape: (8656, 50, 37)
#   Validation sequences shape: (960, 50, 37)
#   Test sequences shape: (960, 50, 37)
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=0.7595, F1 Score=0.6747 | Val: Loss=0.7036, F1 Score=0.6654
# Epoch  10/500 | Train: Loss=0.4059, F1 Score=0.8193 | Val: Loss=0.9644, F1 Score=0.6754
# Epoch  20/500 | Train: Loss=0.3102, F1 Score=0.8816 | Val: Loss=1.6365, F1 Score=0.6251
# Epoch  30/500 | Train: Loss=0.2167, F1 Score=0.9168 | Val: Loss=1.3655, F1 Score=0.7457
# Epoch  40/500 | Train: Loss=0.1623, F1 Score=0.9373 | Val: Loss=1.1609, F1 Score=0.7757
# Epoch  50/500 | Train: Loss=0.1233, F1 Score=0.9543 | Val: Loss=1.1750, F1 Score=0.7661
# Epoch  60/500 | Train: Loss=0.1060, F1 Score=0.9603 | Val: Loss=1.2024, F1 Score=0.7577
# Epoch  70/500 | Train: Loss=0.0865, F1 Score=0.9710 | Val: Loss=1.1145, F1 Score=0.7790
# Epoch  80/500 | Train: Loss=0.0696, F1 Score=0.9741 | Val: Loss=1.5525, F1 Score=0.7310
# Epoch  90/500 | Train: Loss=0.0589, F1 Score=0.9782 | Val: Loss=1.3203, F1 Score=0.7422
# Epoch 100/500 | Train: Loss=0.0681, F1 Score=0.9744 | Val: Loss=1.6750, F1 Score=0.7310
# Early stopping triggered after 105 epochs.
# Best model restored from epoch 55 with val_f1 0.7962
# Split 2/5
#   Training set shape: (86560, 40)
#   Validation set shape: (9600, 40)
#   Test set shape: (9600, 40)
#   Training sequences shape: (8656, 50, 37)
#   Validation sequences shape: (960, 50, 37)
#   Test sequences shape: (960, 50, 37)
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=0.7589, F1 Score=0.6834 | Val: Loss=0.6174, F1 Score=0.7111
# Epoch  10/500 | Train: Loss=0.3613, F1 Score=0.8388 | Val: Loss=0.8522, F1 Score=0.6253
# Epoch  20/500 | Train: Loss=0.2695, F1 Score=0.8947 | Val: Loss=1.1477, F1 Score=0.7153
# Epoch  30/500 | Train: Loss=0.2110, F1 Score=0.9253 | Val: Loss=1.6673, F1 Score=0.6564
# Epoch  40/500 | Train: Loss=0.1635, F1 Score=0.9423 | Val: Loss=1.3726, F1 Score=0.7157
# Epoch  50/500 | Train: Loss=0.1241, F1 Score=0.9554 | Val: Loss=1.5819, F1 Score=0.7250
# Epoch  60/500 | Train: Loss=0.1175, F1 Score=0.9590 | Val: Loss=1.2302, F1 Score=0.7466
# Early stopping triggered after 63 epochs.
# Best model restored from epoch 13 with val_f1 0.8562
# Split 3/5
#   Training set shape: (86560, 40)
#   Validation set shape: (9600, 40)
#   Test set shape: (9600, 40)
#   Training sequences shape: (8656, 50, 37)
#   Validation sequences shape: (960, 50, 37)
#   Test sequences shape: (960, 50, 37)
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=0.7653, F1 Score=0.6758 | Val: Loss=0.7603, F1 Score=0.6205
# Epoch  10/500 | Train: Loss=0.3714, F1 Score=0.8562 | Val: Loss=1.0601, F1 Score=0.7090
# Epoch  20/500 | Train: Loss=0.2086, F1 Score=0.9231 | Val: Loss=0.9715, F1 Score=0.7518
# Epoch  30/500 | Train: Loss=0.1546, F1 Score=0.9437 | Val: Loss=0.7599, F1 Score=0.8197
# Epoch  40/500 | Train: Loss=0.1237, F1 Score=0.9579 | Val: Loss=0.8900, F1 Score=0.8096
# Epoch  50/500 | Train: Loss=0.0965, F1 Score=0.9675 | Val: Loss=0.7686, F1 Score=0.8565
# Epoch  60/500 | Train: Loss=0.0832, F1 Score=0.9699 | Val: Loss=0.8701, F1 Score=0.8248
# Epoch  70/500 | Train: Loss=0.0745, F1 Score=0.9751 | Val: Loss=1.2155, F1 Score=0.7655
# Epoch  80/500 | Train: Loss=0.0529, F1 Score=0.9839 | Val: Loss=0.8031, F1 Score=0.8624
# Epoch  90/500 | Train: Loss=0.0396, F1 Score=0.9877 | Val: Loss=0.7635, F1 Score=0.8682
# Epoch 100/500 | Train: Loss=0.0337, F1 Score=0.9878 | Val: Loss=0.7704, F1 Score=0.8464
# Epoch 110/500 | Train: Loss=0.0373, F1 Score=0.9869 | Val: Loss=0.8401, F1 Score=0.8526
# Early stopping triggered after 119 epochs.
# Best model restored from epoch 69 with val_f1 0.8888
# Split 4/5
#   Training set shape: (86560, 40)
#   Validation set shape: (9600, 40)
#   Test set shape: (9600, 40)
#   Training sequences shape: (8656, 50, 37)
#   Validation sequences shape: (960, 50, 37)
#   Test sequences shape: (960, 50, 37)
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=0.7541, F1 Score=0.6861 | Val: Loss=0.8799, F1 Score=0.5765
# Epoch  10/500 | Train: Loss=0.3483, F1 Score=0.8649 | Val: Loss=1.1229, F1 Score=0.6146
# Epoch  20/500 | Train: Loss=0.2440, F1 Score=0.9160 | Val: Loss=1.0846, F1 Score=0.6941
# Epoch  30/500 | Train: Loss=0.1919, F1 Score=0.9345 | Val: Loss=1.1473, F1 Score=0.7031
# Epoch  40/500 | Train: Loss=0.1450, F1 Score=0.9491 | Val: Loss=1.5759, F1 Score=0.6789
# Epoch  50/500 | Train: Loss=0.1177, F1 Score=0.9595 | Val: Loss=1.7221, F1 Score=0.6854
# Epoch  60/500 | Train: Loss=0.0944, F1 Score=0.9667 | Val: Loss=1.8196, F1 Score=0.6754
# Epoch  70/500 | Train: Loss=0.0818, F1 Score=0.9710 | Val: Loss=1.7531, F1 Score=0.6716
# Epoch  80/500 | Train: Loss=0.0713, F1 Score=0.9749 | Val: Loss=2.0774, F1 Score=0.6645
# Early stopping triggered after 85 epochs.
# Best model restored from epoch 35 with val_f1 0.7176
# Split 5/5
#   Training set shape: (86560, 40)
#   Validation set shape: (9600, 40)
#   Test set shape: (9600, 40)
#   Training sequences shape: (8656, 50, 37)
#   Validation sequences shape: (960, 50, 37)
#   Test sequences shape: (960, 50, 37)
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=0.7450, F1 Score=0.6951 | Val: Loss=0.9545, F1 Score=0.5121
# Epoch  10/500 | Train: Loss=0.3939, F1 Score=0.8249 | Val: Loss=1.1881, F1 Score=0.6340
# Epoch  20/500 | Train: Loss=0.3271, F1 Score=0.8426 | Val: Loss=1.4173, F1 Score=0.6320
# Epoch  30/500 | Train: Loss=0.2715, F1 Score=0.8920 | Val: Loss=1.7196, F1 Score=0.6082
# Epoch  40/500 | Train: Loss=0.2485, F1 Score=0.9039 | Val: Loss=1.4782, F1 Score=0.6837
# Epoch  50/500 | Train: Loss=0.1651, F1 Score=0.9410 | Val: Loss=1.7331, F1 Score=0.6903
# Epoch  60/500 | Train: Loss=0.1168, F1 Score=0.9580 | Val: Loss=1.7079, F1 Score=0.7208
# Epoch  70/500 | Train: Loss=0.1008, F1 Score=0.9626 | Val: Loss=1.4069, F1 Score=0.7701
# Epoch  80/500 | Train: Loss=0.0772, F1 Score=0.9757 | Val: Loss=1.4839, F1 Score=0.7772
# Epoch  90/500 | Train: Loss=0.0687, F1 Score=0.9727 | Val: Loss=1.8380, F1 Score=0.7315
# Epoch 100/500 | Train: Loss=0.0712, F1 Score=0.9741 | Val: Loss=1.3291, F1 Score=0.7753
# Epoch 110/500 | Train: Loss=0.0611, F1 Score=0.9789 | Val: Loss=1.5809, F1 Score=0.7668
# Early stopping triggered after 114 epochs.
# Best model restored from epoch 64 with val_f1 0.8098
# Best score: 0.8137±0.0583
# CPU times: user 13min 46s, sys: 1min 18s, total: 15min 5s
# Wall time: 15min 36s

# %%
def grid_search_cv_rnn(df_training, df_labels, param_grid, fixed_params, cv_params, verbose=True):
    """
    Execute grid search with K-shuffle-split cross-validation for RNN models on time series data.

    Args:
        df: DataFrame with columns ['user_id', 'activity', 'x_axis', 'y_axis', 'z_axis', 'id']
        param_grid: Dict of parameters to test, e.g. {'batch_size': [16, 32], 'rnn_type': ['LSTM', 'GRU']}
        fixed_params: Dict of fixed hyperparameters (hidden_size, learning_rate, window_size, stride, etc.)
        cv_params: Dict of CV settings (epochs, k, patience, criterion, scaler, device, etc.)
        verbose: Print progress for each configuration

    Returns:
        results: Dict with scores for each configuration
        best_config: Dict with best hyperparameter combination
        best_score: Best mean F1 score achieved
    """
    # Generate all parameter combinations
    param_names = list(param_grid.keys())
    param_values = list(param_grid.values())
    combinations = list(product(*param_values))

    results = {}
    best_score = -np.inf
    best_config = None

    total = len(combinations)

    for idx, combo in enumerate(combinations, 1):
        # Create current configuration dict
        current_config = dict(zip(param_names, combo))
        config_str = "_".join([f"{k}_{v}" for k, v in current_config.items()])

        if verbose:
            print(f"\nConfiguration {idx}/{total}:")
            for param, value in current_config.items():
                print(f"  {param}: {value}")

        # Merge current config with fixed parameters
        run_params = {**fixed_params, **current_config}

        # Execute cross-validation
        _, _, fold_scores = k_shuffle_split_cross_validation_round_rnn(
            df_training=df_training,
            df_labels=df_labels,
            experiment_name=config_str,
            **run_params,
            **cv_params
        )

        # Store results
        results[config_str] = fold_scores

        # Track best configuration
        if fold_scores["mean"] > best_score:
            best_score = fold_scores["mean"]
            best_config = current_config.copy()
            if verbose:
                print("  NEW BEST SCORE!")

        if verbose:
            print(f"  F1 Score: {fold_scores['mean']:.4f}±{fold_scores['std']:.4f}")

    return results, best_config, best_score


def plot_top_configurations_rnn(results, k_splits, top_n=5, figsize=(14, 7)):
    """
    Visualise top N RNN configurations with boxplots of F1 scores across CV splits.

    Args:
        results: Dict of results from grid_search_cv_rnn
        k_splits: Number of CV splits used
        top_n: Number of top configurations to display
        figsize: Figure size tuple
    """
    # Sort by mean score
    config_scores = {name: data['mean'] for name, data in results.items()}
    sorted_configs = sorted(config_scores.items(), key=lambda x: x[1], reverse=True)

    # Select top N
    top_configs = sorted_configs[:min(top_n, len(sorted_configs))]

    # Prepare boxplot data
    boxplot_data = []
    labels = []

    # Define a dictionary for replacements, ordered to handle prefixes correctly
    replacements = {
        'batch_size_': 'BS=',
        'learning_rate_': '\nLR=',
        'hidden_layers_': '\nHL=',
        'hidden_size_': '\nHS=',
        'dropout_rate_': '\nDR=',
        'window_size_': '\nWS=',
        'stride_': '\nSTR=',
        'rnn_type_': '\nRNN=',
        'bidirectional_': '\nBIDIR=',
        'l1_lambda_': '\nL1=',
        'l2_lambda_': '\nL2='
    }

    # Replacements for separators
    separator_replacements = {
        '_learning_rate_': '\nLR=',
        '_hidden_layers_': '\nHL=',
        '_hidden_size_': '\nHS=',
        '_dropout_rate_': '\nDR=',
        '_window_size_': '\nWS=',
        '_stride_': '\nSTR=',
        '_rnn_type_': '\nRNN=',
        '_bidirectional_': '\nBIDIR=',
        '_l1_lambda_': '\nL1=',
        '_l2_lambda_': '\nL2=',
        '_': ''
    }

    for config_name, mean_score in top_configs:
        # Extract best score from each split (auto-detect number of splits)
        split_scores = []
        for i in range(k_splits):
            if f'split_{i}' in results[config_name]:
                split_scores.append(results[config_name][f'split_{i}'])
        boxplot_data.append(split_scores)

        # Verify we have the expected number of splits
        if len(split_scores) != k_splits:
            print(f"Warning: Config {config_name} has {len(split_scores)} splits, expected {k_splits}")

        # Create readable label using the replacements dictionary
        readable_label = config_name
        for old, new in replacements.items():
            readable_label = readable_label.replace(old, new)

        # Apply separator replacements
        for old, new in separator_replacements.items():
             readable_label = readable_label.replace(old, new)

        labels.append(f"{readable_label}\n(μ={mean_score:.3f})")

    # Create plot
    fig, ax = plt.subplots(figsize=figsize)
    bp = ax.boxplot(boxplot_data, labels=labels, patch_artist=True,
                    showmeans=True, meanline=True)

    # Styling
    for patch in bp['boxes']:
        patch.set_facecolor('lightblue')
        patch.set_alpha(0.7)

    # Highlight best configuration
    ax.get_xticklabels()[0].set_fontweight('bold')

    ax.set_ylabel('F1 Score')
    ax.set_xlabel('Configuration')
    ax.set_title(f'Top {len(top_configs)} RNN Configurations - F1 Score Distribution Across {k_splits} Splits')
    ax.grid(alpha=0.3, axis='y')

    plt.xticks(rotation=0, ha='center')
    plt.tight_layout()
    plt.show()
